# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
import math
import datetime as dt
import statsmodels.formula.api as sm

# %%
train = pd.read_csv("data/2022_FH.csv")
train = train.dropna(subset = ["Game Prep"])
train.reset_index()
# Out:
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/92136705.py:1: DtypeWarning: Columns (59,63,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv("data/2022_FH.csv")
#        index  Week        Day W L Game Prep Position           Athlete  \
# 0          0     1  Wednesday   W     UConn        B    Maddie Bacskai
# 1          1     1  Wednesday   W     UConn        F     Bente Baekers
# 2          2     1  Wednesday   W     UConn        M       Jordan Carr
# 3          3     1  Wednesday   W     UConn        M   Regan Cornelius
# 4          4     1  Wednesday   W     UConn        B     Shannon Daley
# ...      ...   ...        ...  ..       ...      ...               ...
# 16820  22398    65     Sunday   L  NCAA_UNC        M     Chloe Relford
# 16821  22399    65     Sunday   L  NCAA_UNC       GK   Annabel Skubisz
# 16822  22400    65     Sunday   L  NCAA_UNC        M     Lila Slattery
# 16823  22401    65     Sunday   L  NCAA_UNC        M      Lauren Wadas
# 16824  22402    65     Sunday   L  NCAA_UNC        M  Madeleine Zimmer
#
#       Session Name   Session     Phase Name  ... TSB HSD Decel Sum  \
# 0             GD-2  Training  Whole session  ...    1.00      25.0
# 1             GD-2  Training  Whole session  ...    1.00      52.0
# 2             GD-2  Training  Whole session  ...    1.00      74.0
# 3             GD-2  Training  Whole session  ...    1.00      71.0
# 4             GD-2  Training  Whole session  ...    1.00      87.0
# ...            ...       ...            ...  ...     ...       ...
# 16820     NCAA_UNC      Game    4th quarter  ...    1.17      19.0
# 16821     NCAA_UNC      Game    4th quarter  ...    1.68       1.0
# 16822     NCAA_UNC      Game    4th quarter  ...    0.87       1.0
# 16823     NCAA_UNC      Game    4th quarter  ...    0.88      22.0
# 16824     NCAA_UNC      Game    4th quarter  ...    1.09      21.0
#
#        Acute Decel  Chronic Decel  TSB Decel  HR 4 Percent  HR 5 Percent  \
# 0            12.25          12.25        1.0        11.43%         2.59%
# 1            25.25          25.25        1.0        10.25%         0.80%
# 2            36.50          36.50        1.0        18.93%         1.18%
# 3            34.50          34.50        1.0         9.56%         0.20%
# 4            42.75          42.75        1.0         8.42%         0.56%
# ...            ...            ...        ...           ...           ...
# 16820        36.18          32.85        1.1        23.59%        16.36%
# 16821         4.28           6.16       0.69         8.83%         0.00%
# 16822        19.60          19.29       1.02         0.61%         0.00%
# 16823        27.36          27.92       0.98        24.81%        13.24%
# 16824        36.77          36.49       1.01        21.46%         1.75%
#
#        Percent Above 80    TRIMP Duration (min)
# 0                14.02%  1222.39            216
# 1                11.06%  1123.52            216
# 2                20.11%  1240.37            216
# 3                 9.76%  1132.51            216
# 4                 8.99%  1150.49            216
# ...                 ...      ...            ...
# 16820            39.95%   132.31             22
# 16821             8.83%   128.66             22
# 16822             0.61%   103.11             22
# 16823            38.05%   135.05             22
# 16824            23.21%   127.75             22
#
# [16825 rows x 74 columns]

# %%
train.columns
# Out:
# Index(['Week', 'Day', 'W L', 'Game Prep', 'Position', 'Athlete',
#        'Session Name', 'Session', 'Phase Name', 'Duration', 'Date', 'HR Min',
#        'HR AVG', 'HR Max', 'HR Min Per', 'HR Avg Per', 'HR Max Per', 'HR 1',
#        'HR 2', 'HR 3', 'HR 4', 'HR 5', 'Total Distance', 'Distance/min',
#        'Max Speed', 'Avg Speed', 'Sprints', 'Speed 1', 'Speed 2', 'Speed 3',
#        'Speed 4', 'Speed 5', 'Decel 4', 'Decel 3', 'Decel 2', 'Decel 1',
#        'Accel 1', 'Accel 2', 'Accel 3', 'Accel 4', 'Calories', 'TLScore',
#        'Cardio Load', 'Recovery', 'TL Percent', 'TLScore Acute',
#        'TLScore Chronic', 'TLScore TSB', 'HR Sum 4-5', 'Acute HR Sum',
#        'Chronic HR Sum', 'TSB HR Sum', 'TD Percent', 'Acute TD', 'Chronic TD',
#        'TSB TD', 'HIA', 'Acute HIA', 'Chronic HIA', 'TSB HIA', 'HSD',
#        'Acute HSD', 'Chronic HSD', 'TSB HSD', 'Decel Sum', 'Acute Decel',
#        'Chronic Decel', 'TSB Decel', 'HR 4 Percent', 'HR 5 Percent',
#        'Percent Above 80', 'TRIMP', 'Duration (min)'],
#       dtype='object')

# %% [markdown]
# **Cleaning data**
# - delete all rows that aren't preparing for a game
# - only use fall data (August - Dec) - regular season data
# - don't include HR% because practices are varying length - actual time is more important
# - filter to only include "whole session"
# - filter to players who played more than 800 minutes for the 2022 season
# - filter out goalies

# %%
#train = train[["Week", "W L", "Game Prep", "Position", "Athlete", "Session Name", "Phase Name", "Date", "HR Min", "HR AVG", "HR Max", "HR 1", "HR 2", "HR 3", "HR 4", "HR 5", "Total Distance", "Sprints", "Cardio Load", "TLScore", "Duration (min)"]]

# %%
train["Date"] = pd.to_datetime(train['Date'])
train.Date
# Out:
# 0       2021-08-25
# 1       2021-08-25
# 2       2021-08-25
# 3       2021-08-25
# 4       2021-08-25
#            ...
# 22398   2022-11-20
# 22399   2022-11-20
# 22400   2022-11-20
# 22401   2022-11-20
# 22402   2022-11-20
# Name: Date, Length: 16825, dtype: datetime64[ns]

# %%
#only keeping whole session, dates during season, and field player data
train = train[(train["Phase Name"] == "Whole session") & (train["Date"] >= "2022-08-01") & (train["Date"] <= "2022-12-01") & (train["Position"] != "GK")]

# %%
train.Athlete.unique()
# Out:
# array(['Amelia Albers', 'Bente Baekers', 'Jordan Carr', 'Regan Cornelius',
#        'Shannon Daley', 'Sophie Dix', 'Peyton Halsey', 'Lane Herbert',
#        'Greta Hinke', 'Lauren Hunter', 'Aerin Krys', 'Ana Medina Garcia',
#        'Magnolia Powers', 'Chloe Relford', 'Lila Slattery',
#        'Sophie Thomas', 'Lauren Wadas', 'Madeleine Zimmer',
#        'Maja Zivojnovic', 'Kayla Blas', 'Alia Marshall', 'Katie Jones'],
#       dtype=object)

# %%
#filtering out data for only players with minutes above 800 minutes of playing time over the course of the season (total possible playing time around 1600 minutes)
high_min_players = ['Bente Baekers', 'Shannon Daley', 'Peyton Halsey', 'Ana Medina Garcia', 'Chloe Relford', 'Lauren Wadas','Madeleine Zimmer','Kayla Blas','Alia Marshall']
train = train.loc[train.Athlete.isin(high_min_players),:]
train
# Out:
#        Week        Day  W L Game Prep Position            Athlete  \
# 13150    52  Wednesday  NaN      Iowa        F      Bente Baekers
# 13153    52  Wednesday  NaN      Iowa        B      Shannon Daley
# 13155    52  Wednesday  NaN      Iowa        M      Peyton Halsey
# 13161    52  Wednesday  NaN      Iowa        M  Ana Medina Garcia
# 13163    52  Wednesday  NaN      Iowa        M      Chloe Relford
# ...     ...        ...  ...       ...      ...                ...
# 22260    65     Sunday    L  NCAA_UNC        M      Alia Marshall
# 22261    65     Sunday    L  NCAA_UNC        M  Ana Medina Garcia
# 22262    65     Sunday    L  NCAA_UNC        M      Chloe Relford
# 22265    65     Sunday    L  NCAA_UNC        M       Lauren Wadas
# 22266    65     Sunday    L  NCAA_UNC        M   Madeleine Zimmer
#
#       Session Name   Session     Phase Name Duration  ... TSB HSD  Decel Sum  \
# 13150         GD-3  Training  Whole session  3:22:48  ...    1.00      101.0
# 13153         GD-3  Training  Whole session  3:22:48  ...    1.00      141.0
# 13155         GD-3  Training  Whole session  3:22:48  ...    1.00       65.0
# 13161         GD-3  Training  Whole session  3:22:48  ...    1.00      110.0
# 13163         GD-3  Training  Whole session  3:22:48  ...    1.00      148.0
# ...            ...       ...            ...      ...  ...     ...        ...
# 22260     NCAA_UNC      Game  Whole session  2:26:00  ...    0.97      109.0
# 22261     NCAA_UNC      Game  Whole session  2:26:00  ...    0.95      111.0
# 22262     NCAA_UNC      Game  Whole session  2:26:00  ...    1.17      111.0
# 22265     NCAA_UNC      Game  Whole session  2:26:00  ...    0.88       88.0
# 22266     NCAA_UNC      Game  Whole session  2:26:00  ...    1.09      117.0
#
#        Acute Decel  Chronic Decel  TSB Decel  HR 4 Percent  HR 5 Percent  \
# 13150        32.97          36.74       0.90        23.10%        13.78%
# 13153        33.16          36.50       0.91        17.27%        14.99%
# 13155        26.11          28.82       0.91         4.92%         8.10%
# 13161        26.75          30.93       0.86        21.54%         7.31%
# 13163        34.63          35.86       0.97        14.52%        20.36%
# ...            ...            ...        ...           ...           ...
# 22260        30.74          31.71       0.97        37.04%         8.77%
# 22261        29.15          27.79       1.05        32.74%        22.65%
# 22262        36.18          32.85        1.1        14.42%        22.09%
# 22265        27.36          27.92       0.98        12.90%         8.63%
# 22266        36.77          36.49       1.01         7.51%         2.05%
#
#       Percent Above 80    TRIMP Duration (min)
# 13150           36.88%  1259.05            203
# 13153           32.26%  1233.70            203
# 13155           13.03%  1402.70            203
# 13161           28.85%  1225.25            203
# 13163           34.89%  1233.70            203
# ...                ...      ...            ...
# 22260           45.81%   906.42            146
# 22261           55.39%   955.08            146
# 22262           36.51%   900.33            146
# 22265           21.53%   851.67            146
# 22266            9.57%   778.67            146
#
# [714 rows x 73 columns]

# %%
train['W L'].isnull().sum()
# Out:
# 40

# %%
# dropping all NA W_L values bc that game was a scrimmage
train = train.dropna()
train.head()
# Out:
#        Week       Day W L Game Prep Position        Athlete Session Name  \
# 13879    53  Thursday   W     Maine        F  Bente Baekers         GD-3
# 13880    53  Thursday   W     Maine        B     Kayla Blas         GD-3
# 13883    53  Thursday   W     Maine        B  Shannon Daley         GD-3
# 13885    53  Thursday   W     Maine        M  Peyton Halsey         GD-3
# 13892    53  Thursday   W     Maine        M  Alia Marshall         GD-3
#
#         Session     Phase Name Duration  ... TSB HSD  Decel Sum  Acute Decel  \
# 13879  Training  Whole session  2:02:28  ...    0.94       80.0        32.50
# 13880  Training  Whole session  2:02:28  ...    1.24       62.0        25.67
# 13883  Training  Whole session  2:02:28  ...    0.91       99.0        34.18
# 13885  Training  Whole session  2:02:28  ...    1.14       65.0        29.62
# 13892  Training  Whole session  2:02:28  ...    1.07       57.0        25.48
#
#        Chronic Decel  TSB Decel  HR 4 Percent  HR 5 Percent Percent Above 80  \
# 13879          32.66       0.99        22.77%         7.09%           29.86%
# 13880          29.48       0.87        18.02%         0.00%           18.02%
# 13883          34.54       0.99        20.79%         6.76%           27.56%
# 13885          28.14       1.05        14.02%        26.29%           40.31%
# 13892          26.50       0.96        16.59%         0.14%           16.73%
#
#         TRIMP Duration (min)
# 13879  699.08            122
# 13880  653.16            122
# 13883  683.77            122
# 13885  770.52            122
# 13892  648.05            122
#
# [5 rows x 73 columns]

# %%
#adding a binary column for W and Loss
train.columns = train.columns.str.replace(' ', '_')
train['W_L_binary'] = train['W_L'].apply(lambda x: 0 if x=='L' else 1)
train.head()
# Out:
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/1939409511.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['W_L_binary'] = train['W_L'].apply(lambda x: 0 if x=='L' else 1)
#        Week       Day W_L Game_Prep Position        Athlete Session_Name  \
# 13879    53  Thursday   W     Maine        F  Bente Baekers         GD-3
# 13880    53  Thursday   W     Maine        B     Kayla Blas         GD-3
# 13883    53  Thursday   W     Maine        B  Shannon Daley         GD-3
# 13885    53  Thursday   W     Maine        M  Peyton Halsey         GD-3
# 13892    53  Thursday   W     Maine        M  Alia Marshall         GD-3
#
#         Session     Phase_Name Duration  ... Decel_Sum  Acute_Decel  \
# 13879  Training  Whole session  2:02:28  ...      80.0        32.50
# 13880  Training  Whole session  2:02:28  ...      62.0        25.67
# 13883  Training  Whole session  2:02:28  ...      99.0        34.18
# 13885  Training  Whole session  2:02:28  ...      65.0        29.62
# 13892  Training  Whole session  2:02:28  ...      57.0        25.48
#
#        Chronic_Decel  TSB_Decel  HR_4_Percent  HR_5_Percent  Percent_Above_80  \
# 13879          32.66       0.99        22.77%         7.09%            29.86%
# 13880          29.48       0.87        18.02%         0.00%            18.02%
# 13883          34.54       0.99        20.79%         6.76%            27.56%
# 13885          28.14       1.05        14.02%        26.29%            40.31%
# 13892          26.50       0.96        16.59%         0.14%            16.73%
#
#         TRIMP Duration_(min) W_L_binary
# 13879  699.08            122          1
# 13880  653.16            122          1
# 13883  683.77            122          1
# 13885  770.52            122          1
# 13892  648.05            122          1
#
# [5 rows x 74 columns]

# %%
# Changing HR zones to minutes
train['HR_1'] = train['HR_1'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
train['HR_2'] = train['HR_2'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
train['HR_3'] = train['HR_3'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
train['HR_4'] = train['HR_4'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
train['HR_5'] = train['HR_5'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
train['Acute_HR_Sum'] = train['Acute_HR_Sum'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
train['Chronic_HR_Sum'] = train['Chronic_HR_Sum'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
# Out:
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/4274240502.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['HR_1'] = train['HR_1'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/4274240502.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['HR_2'] = train['HR_2'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/4274240502.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['HR_3'] = train['HR_3'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/4274240502.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['HR_4'] = train['HR_4'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/4274240502.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['HR_5'] = train['HR_5'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/4274240502.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Acute_HR_Sum'] = train['Acute_HR_Sum'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/4274240502.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Chronic_HR_Sum'] = train['Chronic_HR_Sum'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))

# %%
train.corrwith(train.W_L_binary).sort_values(ascending = False)
# Out:
# W_L_binary         1.000000
# Chronic_TD         0.089316
# TLScore_Chronic    0.080723
# HR_AVG             0.054697
# HR_Avg_Per         0.054277
# Recovery           0.050656
# HR_3               0.044949
# Chronic_HR_Sum     0.026896
# Decel_2            0.023906
# Acute_HIA          0.021393
# HR_Max_Per         0.020642
# HR_Max             0.019570
# Chronic_HIA        0.015943
# Speed_5            0.014181
# TLScore_Acute      0.012378
# Accel_4            0.010027
# TLScore            0.007662
# HIA                0.006607
# Accel_3            0.005298
# Accel_2            0.003867
# HR_4               0.003810
# Sprints            0.003068
# Accel_1           -0.000331
# HSD               -0.000598
# Cardio_Load       -0.001973
# Max_Speed         -0.006403
# HR_5              -0.006763
# HR_2              -0.007620
# Speed_4           -0.009407
# Calories          -0.010086
# Decel_3           -0.015878
# Acute_HR_Sum      -0.021777
# Decel_Sum         -0.022557
# TRIMP             -0.026036
# Speed_3           -0.026278
# HR_Min_Per        -0.027399
# HR_Min            -0.027632
# Avg_Speed         -0.029634
# Decel_1           -0.029789
# Acute_Decel       -0.033751
# Distance/min      -0.036929
# Chronic_Decel     -0.036935
# Total_Distance    -0.042645
# Decel_4           -0.043514
# Speed_2           -0.044542
# Acute_TD          -0.051452
# Speed_1           -0.053536
# Duration_(min)    -0.055828
# HR_1              -0.075945
# TSB_HR_Sum        -0.077305
# TLScore_TSB       -0.082661
# Acute_HSD         -0.099410
# TSB_TD            -0.115387
# Week              -0.116805
# Chronic_HSD       -0.127973
# dtype: float64

# %%
## Below here I am playing around with shifting the dataframe. 
# these two lines show that there is an unequal number of observations for each day. 
# I am going to try to fix this by grouping by date and taking the positional avgs for each day. after this, 
# we should be able to shift by date

# %%
train.Athlete.value_counts()
train.Date
# Out:
# 13879   2022-08-25
# 13880   2022-08-25
# 13883   2022-08-25
# 13885   2022-08-25
# 13892   2022-08-25
#            ...
# 22260   2022-11-20
# 22261   2022-11-20
# 22262   2022-11-20
# 22265   2022-11-20
# 22266   2022-11-20
# Name: Date, Length: 674, dtype: datetime64[ns]

# %% [markdown]
# # essentially, we need to make a for loop that assess whether each date is in the dataframe in our date range bc off days wont have data and we need to account for that. If the date is not there, we need to insert 3 rows w F M and B data. When creating the new row of data, you need the date and whether it was a W_L at the following game. Otherwise, every observation can be 0.
#
# steps
# 1. assess if the date appears in train (use TF df)
# 2. if True, continue (just go to beginning of for loop)
# 3. if False, add a new row w the Date

# %%
len(pd.date_range('08/25/2022','11/20/2022'))
# Out:
# 88

# %%
len(train.Date.unique())
# Out:
# 69

# %%
date_range = pd.date_range('08/25/2022','11/20/2022')
#date_range = pd.DataFrame(date_range)
#TF_date_range = 
TF_date_range = pd.DataFrame(date_range.isin(train.Date))
TF_date_range.value_counts()
#date_range
# Out:
# True     69
# False    19
# dtype: int64

# %%
#len(train.Date)
#date_range.isin(train.Date)
train = train.loc[train.Athlete.isin(high_min_players),:]

# %%
#train.columns

# %%
#T_F = pd.DataFrame(date_range.isin(train.Date))
#T_F.iloc[1,0]
date_range = pd.date_range('08/25/2022','11/20/2022')
date_range = pd.DataFrame(date_range)
pd.DataFrame(date_range.isin(train.Date))
# Out:
#         0
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 83  False
# 84  False
# 85  False
# 86  False
# 87  False
#
# [88 rows x 1 columns]

# %%
date_range = pd.date_range('08/25/2022','11/20/2022')
#date_range = pd.DataFrame(date_range)
#TF_date_range = 
TF_date_range = pd.DataFrame(date_range.isin(train.Date))
TF_date_range.value_counts()


#date_range = pd.date_range('08/25/2022','11/20/2022')
#date_range = pd.DataFrame(date_range)
#T_F = pd.DataFrame(date_range.isin(train.Date))

for i in range(len(date_range)):
    a = pd.DataFrame(date_range)
    #print(TF_date_range.iloc[i,0])
    
    if TF_date_range.iloc[i,0] == False:
        
        new_rows = [{'Week':0, 'Day':None, 'W_L':None, 'Game_Prep': None, 'Position':'F', 'Athlete':None,
             'Session_Name':None, 'Session':None, 'Phase_Name':None, 'Duration':0, 'Date':a.iloc[i,0], 'HR_Min':0,
             'HR_AVG':0, 'HR_Max':0, 'HR_Min_Per':0, 'HR_Avg_Per':0, 'HR_Max_Per':0, 'HR_1':0,
             'HR_2':0, 'HR_3':0, 'HR_4':0, 'HR_5':0, 'Total_Distance':0, 'Distance/min':0,
             'Max_Speed':0, 'Avg_Speed':0, 'Sprints':0, 'Speed_1':0, 'Speed_2':0, 'Speed_3':0,
             'Speed_4':0, 'Speed_5':0, 'Decel_4':0, 'Decel_3':0, 'Decel_2':0, 'Decel_1':0,
             'Accel_1':0, 'Accel_2':0, 'Accel_3':0, 'Accel_4':0, 'Calories':0, 'TLScore':0,
             'Cardio_Load':0, 'Recovery':0, 'TL_Percent':0, 'TLScore_Acute':0,
             'TLScore_Chronic':0, 'TLScore_TSB':0, 'HR_Sum_4-5':0, 'Acute_HR_Sum':0,
             'Chronic_HR_Sum':0, 'TSB_HR_Sum':0, 'TD_Percent':0, 'Acute_TD':0, 'Chronic_TD':0,
             'TSB_TD':0, 'HIA':0, 'Acute_HIA':0, 'Chronic_HIA':0, 'TSB_HIA':0, 'HSD':0,
             'Acute_HSD':0, 'Chronic_HSD':0, 'TSB_HSD':0, 'Decel_Sum':0, 'Acute_Decel':0,
             'Chronic_Decel':0, 'TSB_Decel':0, 'HR_4_Percent':None, 'HR_5_Percent':None,
             'Percent_Above_80':None, 'TRIMP':0, 'Duration_(min)':0, 'W_L_binary':0},
                    {'Week':0, 'Day':None, 'W_L':None, 'Game_Prep': None, 'Position':'B', 'Athlete':None,
             'Session_Name':None, 'Session':None, 'Phase_Name':None, 'Duration':0, 'Date':a.iloc[i,0], 'HR_Min':0,
             'HR_AVG':0, 'HR_Max':0, 'HR_Min_Per':0, 'HR_Avg_Per':0, 'HR_Max_Per':0, 'HR_1':0,
             'HR_2':0, 'HR_3':0, 'HR_4':0, 'HR_5':0, 'Total_Distance':0, 'Distance/min':0,
             'Max_Speed':0, 'Avg_Speed':0, 'Sprints':0, 'Speed_1':0, 'Speed_2':0, 'Speed_3':0,
             'Speed_4':0, 'Speed_5':0, 'Decel_4':0, 'Decel_3':0, 'Decel_2':0, 'Decel_1':0,
             'Accel_1':0, 'Accel_2':0, 'Accel_3':0, 'Accel_4':0, 'Calories':0, 'TLScore':0,
             'Cardio_Load':0, 'Recovery':0, 'TL_Percent':0, 'TLScore_Acute':0,
             'TLScore_Chronic':0, 'TLScore_TSB':0, 'HR_Sum_4-5':0, 'Acute_HR_Sum':0,
             'Chronic_HR_Sum':0, 'TSB_HR_Sum':0, 'TD_Percent':0, 'Acute_TD':0, 'Chronic_TD':0,
             'TSB_TD':0, 'HIA':0, 'Acute_HIA':0, 'Chronic_HIA':0, 'TSB_HIA':0, 'HSD':0,
             'Acute_HSD':0, 'Chronic_HSD':0, 'TSB_HSD':0, 'Decel_Sum':0, 'Acute_Decel':0,
             'Chronic_Decel':0, 'TSB_Decel':0, 'HR_4_Percent':None, 'HR_5_Percent':None,
             'Percent_Above_80':None, 'TRIMP':0, 'Duration_(min)':0, 'W_L_binary':0},
                    {'Week':0, 'Day':None, 'W_L':None, 'Game_Prep': None, 'Position':'M', 'Athlete':None,
             'Session_Name':None, 'Session':None, 'Phase_Name':None, 'Duration':0, 'Date':a.iloc[i,0], 'HR_Min':0,
             'HR_AVG':0, 'HR_Max':0, 'HR_Min_Per':0, 'HR_Avg_Per':0, 'HR_Max_Per':0, 'HR_1':0,
             'HR_2':0, 'HR_3':0, 'HR_4':0, 'HR_5':0, 'Total_Distance':0, 'Distance/min':0,
             'Max_Speed':0, 'Avg_Speed':0, 'Sprints':0, 'Speed_1':0, 'Speed_2':0, 'Speed_3':0,
             'Speed_4':0, 'Speed_5':0, 'Decel_4':0, 'Decel_3':0, 'Decel_2':0, 'Decel_1':0,
             'Accel_1':0, 'Accel_2':0, 'Accel_3':0, 'Accel_4':0, 'Calories':0, 'TLScore':0,
             'Cardio_Load':0, 'Recovery':0, 'TL_Percent':0, 'TLScore_Acute':0,
             'TLScore_Chronic':0, 'TLScore_TSB':0, 'HR_Sum_4-5':0, 'Acute_HR_Sum':0,
             'Chronic_HR_Sum':0, 'TSB_HR_Sum':0, 'TD_Percent':0, 'Acute_TD':0, 'Chronic_TD':0,
             'TSB_TD':0, 'HIA':0, 'Acute_HIA':0, 'Chronic_HIA':0, 'TSB_HIA':0, 'HSD':0,
             'Acute_HSD':0, 'Chronic_HSD':0, 'TSB_HSD':0, 'Decel_Sum':0, 'Acute_Decel':0,
             'Chronic_Decel':0, 'TSB_Decel':0, 'HR_4_Percent':None, 'HR_5_Percent':None,
             'Percent_Above_80':None, 'TRIMP':0, 'Duration_(min)':0, 'W_L_binary':0}]
        train = train.append(new_rows, ignore_index=True)
        
train
# Out:
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
# /var/folders/f5/v23gj0gj0_jc4w26rhk8n_100000gn/T/ipykernel_11340/455957058.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_rows, ignore_index=True)
#      Week       Day   W_L Game_Prep Position        Athlete Session_Name  \
# 0      53  Thursday     W     Maine        F  Bente Baekers         GD-3
# 1      53  Thursday     W     Maine        B     Kayla Blas         GD-3
# 2      53  Thursday     W     Maine        B  Shannon Daley         GD-3
# 3      53  Thursday     W     Maine        M  Peyton Halsey         GD-3
# 4      53  Thursday     W     Maine        M  Alia Marshall         GD-3
# ..    ...       ...   ...       ...      ...            ...          ...
# 726     0      None  None      None        B           None         None
# 727     0      None  None      None        M           None         None
# 728     0      None  None      None        F           None         None
# 729     0      None  None      None        B           None         None
# 730     0      None  None      None        M           None         None
#
#       Session     Phase_Name Duration  ... Decel_Sum  Acute_Decel  \
# 0    Training  Whole session  2:02:28  ...      80.0        32.50
# 1    Training  Whole session  2:02:28  ...      62.0        25.67
# 2    Training  Whole session  2:02:28  ...      99.0        34.18
# 3    Training  Whole session  2:02:28  ...      65.0        29.62
# 4    Training  Whole session  2:02:28  ...      57.0        25.48
# ..        ...            ...      ...  ...       ...          ...
# 726      None           None        0  ...       0.0         0.00
# 727      None           None        0  ...       0.0         0.00
# 728      None           None        0  ...       0.0         0.00
# 729      None           None        0  ...       0.0         0.00
# 730      None           None        0  ...       0.0         0.00
#
#      Chronic_Decel  TSB_Decel  HR_4_Percent  HR_5_Percent  Percent_Above_80  \
# 0            32.66       0.99        22.77%         7.09%            29.86%
# 1            29.48       0.87        18.02%         0.00%            18.02%
# 2            34.54       0.99        20.79%         6.76%            27.56%
# 3            28.14       1.05        14.02%        26.29%            40.31%
# 4            26.50       0.96        16.59%         0.14%            16.73%
# ..             ...        ...           ...           ...               ...
# 726           0.00          0          None          None              None
# 727           0.00          0          None          None              None
# 728           0.00          0          None          None              None
# 729           0.00          0          None          None              None
# 730           0.00          0          None          None              None
#
#       TRIMP  Duration_(min)  W_L_binary
# 0    699.08             122           1
# 1    653.16             122           1
# 2    683.77             122           1
# 3    770.52             122           1
# 4    648.05             122           1
# ..      ...             ...         ...
# 726    0.00               0           0
# 727    0.00               0           0
# 728    0.00               0           0
# 729    0.00               0           0
# 730    0.00               0           0
#
# [731 rows x 74 columns]

# %% [markdown]
# ## sort in order of date, then use n/a to fill in

# %%
train.sort_values(by='Date', inplace=True) 
train['W_L'].fillna(method='ffill', inplace=True)
train['W_L'].isna().sum()
train['W_L_binary'] = train['W_L'].apply(lambda x: 0 if x=='L' else 1)
train.corrwith(train.W_L_binary).sort_values(ascending = False)
# Out:
# W_L_binary         1.000000
# TLScore_Chronic    0.086284
# Chronic_TD         0.075295
# HR_AVG             0.072445
# HR_Avg_Per         0.072317
# HR_3               0.063470
# Chronic_HR_Sum     0.060087
# HR_Max_Per         0.059672
# Recovery           0.059574
# HR_Max             0.059298
# Acute_HIA          0.058933
# Chronic_HIA        0.057719
# TLScore_Acute      0.053843
# Decel_2            0.050194
# Chronic_Decel      0.042045
# Acute_TD           0.035955
# Acute_Decel        0.035569
# Max_Speed          0.033941
# Accel_1            0.032235
# Accel_4            0.031671
# Accel_2            0.031380
# HIA                0.031253
# Week               0.030834
# TLScore            0.029710
# Accel_3            0.029631
# Speed_5            0.026633
# Acute_HR_Sum       0.025240
# HR_2               0.023421
# Cardio_Load        0.023264
# TLScore_TSB        0.022454
# HR_4               0.020791
# Calories           0.020769
# Sprints            0.019944
# TSB_TD             0.017991
# HSD                0.016044
# TRIMP              0.014608
# Avg_Speed          0.013534
# HR_Min_Per         0.012380
# HR_Min             0.012141
# Decel_3            0.010656
# Decel_1            0.010249
# Speed_4            0.008757
# Distance/min       0.007121
# Decel_Sum          0.004707
# HR_5               0.004273
# TSB_HR_Sum         0.002630
# Duration_(min)    -0.001805
# Speed_3           -0.004295
# Total_Distance    -0.008903
# Speed_1           -0.011454
# Speed_2           -0.016954
# Decel_4           -0.018708
# Acute_HSD         -0.020503
# Chronic_HSD       -0.025378
# HR_1              -0.038483
# dtype: float64

# %%
train.Date.value_counts()
# Out:
# 2022-08-25    18
# 2022-09-27    18
# 2022-09-13    18
# 2022-09-07    17
# 2022-09-28    17
#               ..
# 2022-10-22     3
# 2022-09-20     3
# 2022-09-19     3
# 2022-10-17     3
# 2022-09-12     3
# Name: Date, Length: 88, dtype: int64

# %%
date_range = pd.date_range('08/25/2022','11/20/2022')
date_range = pd.DataFrame(date_range)
TF_date_range = date_range.isin(train.Date)
date_range
# Out:
#             0
# 0  2022-08-25
# 1  2022-08-26
# 2  2022-08-27
# 3  2022-08-28
# 4  2022-08-29
# ..        ...
# 83 2022-11-16
# 84 2022-11-17
# 85 2022-11-18
# 86 2022-11-19
# 87 2022-11-20
#
# [88 rows x 1 columns]

# %%
#i = 0
date_range = pd.date_range('08/25/2022','11/20/2022')
#train.loc[train.Date.isin(train.Date)]
date_range.isin(train.Date)
# Out:
#        0
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True
# ..   ...
# 83  True
# 84  True
# 85  True
# 86  True
# 87  True
#
# [88 rows x 1 columns]

# %%
grouped_train = train.groupby(['Date','Position'])
#print(grouped_train.size().to_string())
gtrain_date_pos = grouped_train.mean()
gtrain_date_pos
# Out:
#                      Week     HR_Min      HR_AVG      HR_Max  HR_Min_Per  \
# Date       Position
# 2022-08-25 B         53.0  74.500000  123.500000  179.000000   37.000000
#            F         53.0  82.000000  124.000000  200.500000   41.000000
#            M         53.0  59.583333  129.166667  197.000000   30.000000
# 2022-08-26 B         53.0  61.000000  115.000000  178.000000   30.500000
#            F         53.0  78.000000  122.000000  183.000000   39.000000
# ...                   ...        ...         ...         ...         ...
# 2022-11-19 F         65.0  70.000000  109.000000  190.000000   35.000000
#            M         65.0  43.166667  108.666667  199.000000   21.833333
# 2022-11-20 B         65.0  84.500000  146.000000  194.000000   42.000000
#            F         65.0  58.000000  154.000000  202.000000   29.000000
#            M         65.0  42.666667  145.833333  206.166667   21.500000
#
#                      HR_Avg_Per  HR_Max_Per       HR_1       HR_2       HR_3  \
# Date       Position
# 2022-08-25 B          61.250000   88.750000  27.500000  14.750000  13.500000
#            F          62.500000  101.500000  34.500000  20.500000   8.000000
#            M          64.916667   98.833333  23.333333  19.166667  13.416667
# 2022-08-26 B          57.000000   88.000000  34.000000  14.500000  15.000000
#            F          62.000000   92.000000  43.000000  16.000000  13.000000
# ...                         ...         ...        ...        ...        ...
# 2022-11-19 F          55.000000   96.000000  28.000000  15.000000  10.000000
#            M          54.333333   99.833333  22.500000  12.333333   7.500000
# 2022-11-20 B          72.500000   96.000000  22.000000  24.000000  23.000000
#            F          78.000000  102.000000  10.000000  31.000000  24.000000
#            M          73.166667  103.500000  18.833333  28.833333  22.166667
#
#                      ...  Chronic_HIA          HSD   Acute_HSD  Chronic_HSD  \
# Date       Position  ...
# 2022-08-25 B         ...    32.725000   405.750000  272.650000   260.145000
#            F         ...    38.460000   350.000000  260.610000   276.110000
#            M         ...    37.215000   410.250000  324.761667   293.058333
# 2022-08-26 B         ...    32.435000   266.500000  280.890000   256.410000
#            F         ...    38.120000   238.000000  252.040000   270.770000
# ...                  ...          ...          ...         ...          ...
# 2022-11-19 F         ...    32.880000    76.000000  301.140000   327.470000
#            M         ...    34.893333   162.500000  364.363333   375.616667
# 2022-11-20 B         ...    31.705000  1450.000000  371.465000   371.065000
#            F         ...    32.530000  1043.000000  328.500000   331.350000
#            M         ...    34.801667  1611.833333  396.076667   387.156667
#
#                       Decel_Sum  Acute_Decel  Chronic_Decel       TRIMP  \
# Date       Position
# 2022-08-25 B          43.000000    29.925000      32.010000  473.797500
#            F          46.500000    32.500000      32.660000  483.085000
#            M          38.000000    31.476667      31.048333  495.518333
# 2022-08-26 B          37.500000    30.255000      31.930000  488.430000
#            F          26.000000    30.180000      32.550000  518.160000
# ...                         ...          ...            ...         ...
# 2022-11-19 F          24.000000    26.210000      27.830000  418.970000
#            M          32.166667    30.960000      31.470000  417.688333
# 2022-11-20 B         123.000000    33.125000      33.080000  888.165000
#            F          86.000000    27.500000      27.810000  936.830000
#            M         108.500000    32.021667      31.420000  887.153333
#
#                      Duration_(min)  W_L_binary
# Date       Position
# 2022-08-25 B                   90.0         1.0
#            F                   90.0         1.0
#            M                   90.0         1.0
# 2022-08-26 B                  102.0         1.0
#            F                  102.0         1.0
# ...                             ...         ...
# 2022-11-19 F                   92.0         0.0
#            M                   92.0         0.0
# 2022-11-20 B                  146.0         0.0
#            F                  146.0         0.0
#            M                  146.0         0.0
#
# [255 rows x 55 columns]

# %%
gtrain_date_pos.nlevel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 gtrain_date_pos.nlevel()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'nlevel'

# %%
gtrain_date_pos['Position'].value_counts()

B 69
F 88
M 88
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 gtrain_date_pos['Position'].value_counts()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Position'

# %%
#print(list(gtrain_date_pos.index.value_counts()))
#a = gtrain_date_pos.reset_index(inplace=True)
gtrain_date_pos.Date.value_counts(ascending = True).head(30)
# Out:
# 2022-09-14    2
# 2022-11-16    2
# 2022-11-15    2
# 2022-11-13    2
# 2022-11-12    2
# 2022-09-24    2
# 2022-09-03    2
# 2022-09-22    2
# 2022-10-25    2
# 2022-08-25    3
# 2022-10-26    3
# 2022-10-21    3
# 2022-10-16    3
# 2022-10-19    3
# 2022-10-18    3
# 2022-10-15    3
# 2022-10-14    3
# 2022-10-13    3
# 2022-10-20    3
# 2022-10-27    3
# 2022-11-02    3
# 2022-10-29    3
# 2022-10-30    3
# 2022-10-12    3
# 2022-11-03    3
# 2022-11-04    3
# 2022-11-05    3
# 2022-11-06    3
# 2022-11-08    3
# 2022-11-09    3
# Name: Date, dtype: int64

# %% [markdown]
# ## once we r here
#
# 1. run corr, decide which vars to keep and what to drop
# 2. shift the data by 4 days (have to shift by index bc some of the dates to not have data for all 3 positions)
# 3. run the logit regression
